# %% [markdown]
# # Python ETL Data Crawling

# %% [markdown]
# ## 使用requests.get

# %%
import requests
res = requests.get('https://www.python.org/')
#print res.text
print res.status_code 
print res.headers['content-type']
# Out:
# 200
# text/html; charset=utf-8

# %% [markdown]
# ## 使用requests.post

# %%
import requests
payload = {
'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation':'60831846-f0e4-47f6-9b5b-46323ebdcef7',
'SearchDate':'2014/06/18',
'SearchTime':'10:30',
'SearchWay':'DepartureInMandarin'
}
res = requests.post('http://www.thsrc.com.tw/tw/TimeTable/SearchResult', data=payload)
print res.text
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
# <meta charset="utf-8" />
# <head>
#  <!--[if lt IE 9]>
# <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
# <script src="/Content/dist/html5shiv.js" type="text/javaScript"></script>
# <script src="/Content/dist/html5shiv-printshiv.js" type="text/javaScript"></script>
# <![endif]-->
# <!--[if IE 7]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 8]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
# <!--[if IE 6]>
# <link href="/Content/css/pngFix.css" rel="stylesheet" type="text/css" />
# <script src="/Content/iepngfix/iepngfix_tilebg.js" type="text/javaScript"></script>
# <![endif]-->
#     <title>
# 	台灣高鐵 Taiwan High Speed Rail
# </title>
#     <link rel="shortcut icon" href="/Content/favicon/favicon.ico" />
#
#
# <script src="/Content/Script/jquery-1.6.1.min.js" type="text/javascript"></script>
# <script src="/Content/Script/jquery-ui-1.8.5.custom.min.js" type="text/javaScript"></script>
# <script src="/Content/Script/jquery.ui.datepicker.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.mousewheel-3.0.2.pack.js" type="text/javaScript"></script>
# <script src="/Content/Script/fancybox/jquery.fancybox-1.3.1.js" type="text/javaScript"></script>
# <script src="/Content/Script/dateTool.js" type="text/javaScript"></script>
# <script src="/Content/Script/THSRC.Common.js" type="text/javaScript"></script>
#     <script type="text/javascript" src="/Content/Script/forListMenu.js"></script>
#     <link href="/Content/css/common_list_menu.css" rel="stylesheet" type="text/css" />
#     <link href="/Content/css/error.css" rel="stylesheet" type="text/css" />
# </head>
#
# <body>
#     <div class="wrapper">
#
#         <header>
#
#             <h1><a href="/">台灣高鐵</a></h1>
#             <aside class="top_aside">
#
#         <ul>
#             <li><a href="/tw/Home/Index">繁體中文</a></li>
#
#         <li class="addLine"><a href="http://www5.thsrc.com.tw/jp/">日本語</a> </li>
#             <li class="addLine"><a href="http://www5.thsrc.com.tw/en/">English</a></li>
#         </ul>
# <form action="/tw/Home/Search" id="formWholeSiteSearch" method="post" name="formWholeSiteSearch">
#     <label for="serchBar"></label>
#
#     <input id="searchBar" name="searchBar" type="text" value="" />
#     <a href="javascript:;"  onkeypress="SubmitSearch()" onclick="SubmitSearch()">立即搜尋</a>
# </form>
# <script>
#     function SubmitSearch() {
#         var keyword = $("#searchBar").val();
#         if (keyword != "") {
#             $("#formWholeSiteSearch").submit();
#         } else {
#             alert("請輸入搜尋內容");
#         }
#     }
# </script>
#             </aside>
#
#
#  <script type="text/javascript" src="/Content/Script/forListMenu.js"></script>
#   <script type="text/javascript" src="/Content/Script/jquery.bgiframe.js"></script>
#  <link href="/Content/css/common_list_menu.css" rel="stylesheet" type="text/css">
#  <link href="/Content/css/common_list_menu_en_jp.css" rel="stylesheet" type="text/css">
#
#
# <nav class="top_nav top_nav_tw">
#     <ul>
#     <li class="nav_hot" ><a  title = "優惠活動">優惠活動</a>
#                                 <div class="dl">
#                                     <div class="first_list">
#                                         <div class="has_photo_list"><img src="/Content/UploadFiles/index/nav_hot.jpg" width="200" height="120" alt="優惠活動" title = "優惠活動"></div>
#                                         <div title =密集方便，高鐵提供您準點可靠的列車服務。 class="photo_list_word">密集方便，高鐵提供您準點可靠的列車服務。</div>
#                                     </div>
#                                     <div class="list_area list_area_tw">
#                                 <div title ="購票優惠" class="dtnolink">購票優惠</div>
# <div class="dd">
#                             <a title = "早鳥優惠"  href="/tw/Article/ArticleContent/7039d17d-1463-4c14-ad93-4d491dedcad5" alt = "早鳥優惠"  >
#                             早鳥優惠
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "信用卡優惠專區"  href="/tw/Article/ArticleContent/566d6bff-4427-461d-8b88-b6c4868f75c9" alt = "信用卡優惠專區"  >
#                             信用卡優惠專區
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "交通聯票"  href="/tw/Article/ArticleContent/5af4ceb8-4c6f-44ec-b02d-0c398c0ad917" alt = "交通聯票"  >
#                             交通聯票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "活動套票"  href="/tw/Article/ArticleContent/d794b386-96a7-445c-8a50-160862a037e9" alt = "活動套票"  >
#                             活動套票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "大學生優惠"  href="/tw/Article/ArticleContent/530e869c-479d-441a-a4b4-61a8166827e9" alt = "大學生優惠"  >
#                             大學生優惠
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "大學生團體返鄉優惠"  href="/tw/Article/ArticleContent/2c7147fa-7836-42d0-8934-e46f1548cd13" alt = "大學生團體返鄉優惠"  >
#                             大學生團體返鄉優惠
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "60-64歲熟年優惠"  href="/tw/Article/ArticleContent/6f40e8c2-6725-4718-9abd-6c0c3aadf834" alt = "60-64歲熟年優惠"  >
#                             60-64歲熟年優惠
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "平日離峰92折"  href="/tw/Article/ArticleContent/e75eb64d-0cbf-42de-a7fb-dc43116be985" alt = "平日離峰92折"  >
#                             平日離峰92折
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "30人以上團體優惠"  href="/tw/Article/ArticleContent/78d182eb-0e86-4343-8b5f-4199036daa7b" alt = "30人以上團體優惠"  >
#                             30人以上團體優惠
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "校外教學優惠"  href="/tw/Article/ArticleContent/ca09cf02-8f65-4f87-b25e-31cb9c0e187b" alt = "校外教學優惠"  >
#                             校外教學優惠
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "團體訂票"  href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" alt = "團體訂票"  >
#                             團體訂票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "回數票"  href="/tw/Article/ArticleContent/8f06ca76-ab2d-4b77-bc20-73218ce3b892" alt = "回數票"  >
#                             回數票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "定期票"  href="/tw/Article/ArticleContent/b7b46e29-424c-4fc4-8ec7-0ab3031f2c9c" alt = "定期票"  >
#                             定期票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "企業會員"  href="/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" alt = "企業會員"  >
#                             企業會員
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "高鐵假期[Will open a new window ]"  href="http://tholiday.thsrc.com.tw/TC/index.aspx" alt = "高鐵假期[Will open a new window ]" target="_blank" >
#                             高鐵假期<span style='display:none;'>[Will open a new window ]</span>
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "飯店聯票"  href="/tw/Article/ArticleContent/1fa66994-818b-43fa-b72b-0ccc2c281b9d" alt = "飯店聯票"  >
#                             飯店聯票<em></em>
#                             </a>
#                             </div>
# <div title ="最新公告" class="dtnolink">最新公告</div>
# <div class="dd">
#                             <a title = "最新消息"  href="/tw/News/Index" alt = "最新消息"  >
#                             最新消息
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "列車運行狀況"  href="/tw/Operation/Index" alt = "列車運行狀況"  >
#                             列車運行狀況<em></em>
#                             </a>
#                             </div>
# <div title ="熱門活動" class="dtnolink">熱門活動</div>
# <div class="dd">
#                             <a title = "歡樂卡通列車[Will open a new window ]"  href="http://www.thsrc.com.tw/event/2013_CartoonTrain/page3.htm" alt = "歡樂卡通列車[Will open a new window ]" target="_blank" >
#                             歡樂卡通列車<span style='display:none;'>[Will open a new window ]</span>
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "高鐵營隊"  href="/tw/TCamp/Index" alt = "高鐵營隊"  >
#                             高鐵營隊
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "活動合作"  href="/tw/Article/ArticleContent/99ba7783-c46e-4b68-849b-e9084e5a0e15" alt = "活動合作"  >
#                             活動合作<em></em>
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
#
#                                 </div>
#                             </li>
# <li class="nav_ticket" ><a  title = "購票資訊">購票資訊</a>
#                                 <div class="dl">
#                                     <div class="first_list">
#                                         <div class="has_photo_list"><img src="/Content/UploadFiles/index/nav_ticket.jpg" width="200" height="120" alt="購票資訊" title = "購票資訊"></div>
#                                         <div title =最新的購票優惠及列車資訊，快速掌握高鐵動態。 class="photo_list_word">最新的購票優惠及列車資訊，快速掌握高鐵動態。</div>
#                                     </div>
#                                     <div class="list_area list_area_tw">
#                                 <div title ="快速查詢" class="dtnolink">快速查詢</div>
# <div class="dd">
#                             <a title = "時刻表與票價查詢"  href="/tw/TimeTable/SearchResult" alt = "時刻表與票價查詢"  >
#                             時刻表與票價查詢
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "T Express 搭乘紀錄[Will open a new window ]"  href="http://www4.thsrc.com.tw/tc/TExp/page_01.asp" alt = "T Express 搭乘紀錄[Will open a new window ]" target="_blank" >
#                             T Express 搭乘紀錄<span style='display:none;'>[Will open a new window ]</span>
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "回數 / 定期票搭乘紀錄[Will open a new window ]"  href="http://www4.thsrc.com.tw/webEQM/page_01.asp" alt = "回數 / 定期票搭乘紀錄[Will open a new window ]" target="_blank" >
#                             回數 / 定期票搭乘紀錄<span style='display:none;'>[Will open a new window ]</span>
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "悠遊聯名卡搭乘紀錄[Will open a new window ]"  href="http://queryweb.tscc.com.tw/thsrc_web/" alt = "悠遊聯名卡搭乘紀錄[Will open a new window ]" target="_blank" >
#                             悠遊聯名卡搭乘紀錄<span style='display:none;'>[Will open a new window ]</span><span style='display:none;'>[Will open a new window ]</span><em></em>
#                             </a>
#                             </div>
# <div title ="票種說明" class="dtnolink">票種說明</div>
# <div class="dd">
#                             <a title = "票價產品一覽表"  href="/tw/Article/ArticleContent/caa6fac8-b875-4ad6-b1e6-96c2902d12a6" alt = "票價產品一覽表"  >
#                             票價產品一覽表<em></em>
#                             </a>
#                             </div>
# <div title ="如何購票" class="dtnolink">如何購票</div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "網路訂票"  href="/tw/Article/ArticleContent/dea241a9-fe69-4e9d-b9a5-6caed6e486d6" alt = "網路訂票"  >
#                             網路訂票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "T Express 手機購票"  href="/tw/Article/ArticleContent/4d262503-84bc-4963-a58e-4ca1a6453ad3" alt = "T Express 手機購票"  >
#                             T Express 手機購票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "便利商店購票"  href="/tw/Article/ArticleContent/baba745a-d802-440c-b762-3eef37b96b60" alt = "便利商店購票"  >
#                             便利商店購票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "自動語音訂位服務"  href="/tw/Article/ArticleContent/7a96ad53-6efa-4c58-bb17-70c9f649b4e3" alt = "自動語音訂位服務"  >
#                             自動語音訂位服務
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "自動售票機購票"  href="/tw/Article/ArticleContent/6be4173c-91dc-4d06-ae3e-a19de420a237" alt = "自動售票機購票"  >
#                             自動售票機購票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "團體訂票"  href="/tw/Article/ArticleContent/41421730-b8ab-4fe3-b251-89e32cba8453" alt = "團體訂票"  >
#                             團體訂票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "車站窗口購票"  href="/tw/Article/ArticleContent/43d5e5e2-3777-46b9-bc8f-8b5b579b50ed" alt = "車站窗口購票"  >
#                             車站窗口購票
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "悠遊聯名卡"  href="/tw/Article/ArticleContent/27bf64ed-5a99-4c0f-9021-dbe609998cdb" alt = "悠遊聯名卡"  >
#                             悠遊聯名卡
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "無障礙服務"  href="/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" alt = "無障礙服務"  >
#                             無障礙服務<em></em>
#                             </a>
#                             </div>
# <div title ="企業會員" class="dtnolink">企業會員</div>
# <div class="dd">
#                             <a title = "加入企業會員"  href="http://www.thsrc.com.tw/tw/Article/ArticleContent/376238fd-2f6d-48f8-b070-9f2ea61b14b5" alt = "加入企業會員"  >
#                             加入企業會員<em></em>
#                             </a>
#                             </div>
# <div title ="相關法規" class="dtnolink">相關法規</div>
# <div class="dd">
#                             <a title = "相關法規"  href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" alt = "相關法規"  >
#                             相關法規<em></em>
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
#
#                                 </div>
#                             </li>
# <li class="nav_info" ><a  title = "乘車指南">乘車指南</a>
#                                 <div class="dl">
#                                     <div class="first_list">
#                                         <div class="has_photo_list"><img src="/Content/UploadFiles/index/nav_info.jpg" width="200" height="120" alt="乘車指南" title = "乘車指南"></div>
#                                         <div title =舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。 class="photo_list_word">舒適的環境及便捷的交通轉乘，高鐵與您共創美好旅程。</div>
#                                     </div>
#                                     <div class="list_area list_area_tw">
#                                 <div title ="車站資訊" class="dtnolink">車站資訊</div>
# <div class="dd">
#                             <a title = "台北站"  href="/tw/StationInfo/Prospect/977abb69-413a-4ccf-a109-0272c24fd490" alt = "台北站"  >
#                             台北站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "板橋站"  href="/tw/StationInfo/Prospect/e6e26e66-7dc1-458f-b2f3-71ce65fdc95f" alt = "板橋站"  >
#                             板橋站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "桃園站"  href="/tw/StationInfo/Prospect/fbd828d8-b1da-4b06-a3bd-680cdca4d2cd" alt = "桃園站"  >
#                             桃園站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "新竹站"  href="/tw/StationInfo/Prospect/a7a04c89-900b-4798-95a3-c01c455622f4" alt = "新竹站"  >
#                             新竹站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "台中站"  href="/tw/StationInfo/Prospect/3301e395-46b8-47aa-aa37-139e15708779" alt = "台中站"  >
#                             台中站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "嘉義站"  href="/tw/StationInfo/Prospect/60831846-f0e4-47f6-9b5b-46323ebdcef7" alt = "嘉義站"  >
#                             嘉義站
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "台南站"  href="/tw/StationInfo/Prospect/9c5ac6ca-ec89-48f8-aab0-41b738cb1814" alt = "台南站"  >
#                             台南站
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "左營站"  href="/tw/StationInfo/Prospect/f2519629-5973-4d08-913b-479cce78a356" alt = "左營站"  >
#                             左營站<em></em>
#                             </a>
#                             </div>
# <div title ="轉乘服務" class="dtnolink">轉乘服務</div>
# <div class="dd">
#                             <a title = "轉乘服務總覽"  href="/tw/Article/ArticleContent/c2a8fd9d-ced6-43b1-9297-9eab4127b5ff" alt = "轉乘服務總覽"  >
#                             轉乘服務總覽<em></em>
#                             </a>
#                             </div>
# <div title ="服務與設施" class="dtnolink">服務與設施</div>
# <div class="dd">
#                             <a title = "服務與設施總覽"  href="/tw/Article/ArticleContent/9915abee-dc70-4ba3-9f6d-c425873c3475" alt = "服務與設施總覽"  >
#                             服務與設施總覽
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "無障礙服務"  href="http://www.thsrc.com.tw/tw/Article/ArticleContent/dba4ecd0-5ef0-45d2-aa64-bcecdf7d5fde" alt = "無障礙服務"  >
#                             無障礙服務
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "車廂介紹"  href="/tw/StationInfo/Accommondation" alt = "車廂介紹"  >
#                             車廂介紹
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "商務車廂服務"  href="/tw/Article/ArticleContent/80b25339-692c-40fd-9c7f-29b84f5c6324" alt = "商務車廂服務"  >
#                             商務車廂服務
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "標準車廂服務"  href="/tw/Article/ArticleContent/6a7933d7-782f-46e5-bd7e-0da0452d2830" alt = "標準車廂服務"  >
#                             標準車廂服務
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "無障礙車廂服務"  href="/tw/Article/ArticleContent/54334dfd-46a3-4306-8584-cb9600e19d9f" alt = "無障礙車廂服務"  >
#                             無障礙車廂服務<em></em>
#                             </a>
#                             </div>
# <div title ="享樂購物趣" class="dtnolink">享樂購物趣</div>
# <div class="dd">
#                             <a title = "列車販售"  href="http://www.thsrc.com.tw/tw/TShop/TrainShopping" alt = "列車販售"  >
#                             列車販售
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "紀念商品"  href="http://www.thsrc.com.tw/tw/Souvenir" alt = "紀念商品"  >
#                             紀念商品
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "高鐵市集"  href="https://www.thsrc.com.tw/tw/Tmarket/Index/3301e395-46b8-47aa-aa37-139e15708779" alt = "高鐵市集"  >
#                             高鐵市集
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "車站販售"  href="https://www.thsrc.com.tw/tw/TShop/FoodCourt" alt = "車站販售"  >
#                             車站販售<em></em>
#                             </a>
#                             </div>
# <div title ="注意事項" class="dtnolink">注意事項</div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "乘車須知"  href="/tw/Article/ArticleContent/2f73bfbb-d9bb-400e-b806-f6c5ba539368" alt = "乘車須知"  >
#                             乘車須知
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "驗票閘門及通關"  href="/tw/Article/ArticleContent/4f77e9e6-f337-4af4-8f60-fbd6054e608f" alt = "驗票閘門及通關"  >
#                             驗票閘門及通關
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "乘車安全"  href="/tw/Article/ArticleContent/b5eac66f-877a-4937-bfdd-0baad3c0cbb6" alt = "乘車安全"  >
#                             乘車安全<em></em>
#                             </a>
#                             </div>
# <div title ="高鐵百科" class="dtnolink">高鐵百科</div>
# <div class="dd">
#                             <a title = "地震防護與應變[Will open a new window ]"  href="http://www.thsrc.com.tw/event/Encyclopedia/Earthquake/index.html" alt = "地震防護與應變[Will open a new window ]" target="_blank" >
#                             地震防護與應變<span style='display:none;'>[Will open a new window ]</span><span style='display:none;'>[Will open a new window ]</span><em></em>
#                             </a>
#                             </div>
#
#                             </div>
#
#                                 </div>
#                             </li>
# <li class="nav_about" ><a href="/tw/Article/ArticleContent/841afa46-f7d7-4747-889c-b03469fdb455" title = "關於高鐵">關於高鐵</a>
#                                 <div class="dl">
#                                     <div class="first_list">
#                                         <div class="has_photo_list"><img src="/Content/UploadFiles/index/nav_about.jpg" width="200" height="120" alt="關於高鐵" title = "關於高鐵"></div>
#                                         <div title =旅遊購物輕鬆滿足，高鐵生活好便利！ class="photo_list_word">旅遊購物輕鬆滿足，高鐵生活好便利！</div>
#                                     </div>
#                                     <div class="list_area list_area_tw">
#                                 <div title ="企業資訊" class="dtnolink">企業資訊</div>
# <div class="dd">
#                             <a title = "企業社會責任[Will open a new window ]"  href="http://www2.thsrc.com.tw/Content/UploadFiles/CorporateResponsibility.pdf" alt = "企業社會責任[Will open a new window ]" target="_blank" >
#                             企業社會責任<span style='display:none;'>[Will open a new window ]</span>
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "組織系統圖"  href="/tw/Article/ArticleContent/07a19853-350d-42e4-b0c6-5bdd76c3ce7d" alt = "組織系統圖"  >
#                             組織系統圖
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "董事會及經營團隊"  href="/tw/Article/ArticleContent/eba2a49b-df9a-4955-9582-d3bfab0892d5" alt = "董事會及經營團隊"  >
#                             董事會及經營團隊
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "大事紀要"  href="/tw/Article/ArticleContent/b792e45d-5416-469b-82fd-ed383bef4691" alt = "大事紀要"  >
#                             大事紀要
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "企業識別"  href="/tw/Article/ArticleContent/605d1cb2-2d98-4d73-9586-7e8363ee44e3" alt = "企業識別"  >
#                             企業識別
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "專業認證"  href="/tw/Article/ArticleContent/63d60a32-0600-4cd7-ac37-6ad8316b7f1e" alt = "專業認證"  >
#                             專業認證
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "環保與研發支出資訊"  href="/tw/Article/ArticleContent/34d8a763-9a98-4478-919c-6b88d07fecaa" alt = "環保與研發支出資訊"  >
#                             環保與研發支出資訊<em></em>
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div title ="營運現狀" class="dtnolink">營運現狀</div>
# <div class="dd">
#                             <a title = "營運業務說明"  href="/tw/Article/ArticleContent/102eeb32-1dd5-4b3d-85d3-c25de33469aa" alt = "營運業務說明"  >
#                             營運業務說明
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "營運年度概況"  href="/tw/Article/ArticleContent/1e07f685-045e-403c-bf92-88c2d86bf826" alt = "營運年度概況"  >
#                             營運年度概況
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "站區開發"  href="/tw/Article/ArticleContent/d2fb4fb6-4ccd-47c0-ba25-4d69ae08dda7" alt = "站區開發"  >
#                             站區開發
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "新建車站"  href="/tw/Article/ArticleContent/b4ee3c28-9058-4575-adfb-94b294441260" alt = "新建車站"  >
#                             新建車站<em></em>
#                             </a>
#                             </div>
# <div title ="股務資訊" class="dtnolink">股務資訊</div>
# <div class="dd">
#                             <a title = "基本資料"  href="/tw/StockInfo/Index" alt = "基本資料"  >
#                             基本資料
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "文件下載"  href="/tw/StockInfo/DocumentDownload" alt = "文件下載"  >
#                             文件下載
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "重大訊息"  href="/tw/StockInfo/GreatNewsIndex" alt = "重大訊息"  >
#                             重大訊息
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "自結損益"  href="/tw/Article/ArticleContent/5aebf2ce-4186-463d-8a15-46234169e05b" alt = "自結損益"  >
#                             自結損益<em></em>
#                             </a>
#                             </div>
# <div title ="政策法規" class="dtnolink">政策法規</div>
# <div class="dd">
#                             <a title = "線上購票交易注意事項"  href="/tw/Article/ArticleContent/291d80fe-080f-4442-90d0-9a9b82f119e5" alt = "線上購票交易注意事項"  >
#                             線上購票交易注意事項
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "個人資料保護專區"  href="/tw/Article/ArticleContent/d1fa3bcb-a016-47e2-88c6-7b7cbed00ed5" alt = "個人資料保護專區"  >
#                             個人資料保護專區
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "相關法規"  href="/tw/Article/ArticleContent/7de57796-db08-4d94-b183-bd62618859db" alt = "相關法規"  >
#                             相關法規<em></em>
#                             </a>
#                             </div>
# <div title ="合作夥伴" class="dtnolink">合作夥伴</div>
# <div class="dd">
#                             <a title = "招標資訊"  href="/tw/Tendering" alt = "招標資訊"  >
#                             招標資訊
#                             </a>
#                             </div>
#
#                             </div>
# <div class="list_line"></div>
# <div class="list_area list_area_tw">
#                                 <div class="dd">
#                             <a title = "業務申辦 "  href="/tw/Article/ArticleContent/4efcd63f-6d07-4363-8a52-26a4a4f462cb" alt = "業務申辦 "  >
#                             業務申辦 <em></em>
#                             </a>
#                             </div>
# <div title ="加入高鐵" class="dtnolink">加入高鐵</div>
# <div class="dd">
#                             <a title = "幸福高鐵"  href="/tw/Article/ArticleContent/91918831-5417-459a-9774-312f31a66ca2" alt = "幸福高鐵"  >
#                             幸福高鐵
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "甄選流程"  href="/tw/Article/ArticleContent/923049a0-10dd-4c2f-927b-66e470c9c16e" alt = "甄選流程"  >
#                             甄選流程
#                             </a>
#                             </div>
# <div class="dd">
#                             <a title = "我要應徵[Will open a new window ]"  href="http://ehrweb.104.com.tw/job.do?uno=16446274" alt = "我要應徵[Will open a new window ]" target="_blank" >
#                             我要應徵<span style='display:none;'>[Will open a new window ]</span><span style='display:none;'>[Will open a new window ]</span><em></em>
#                             </a>
#                             </div>
#
#                             </div>
#
#                                 </div>
#                             </li>
# <li class="nav_life">
#                                 <a href="http://tholiday.thsrc.com.tw/" alt = "高鐵假期" title = "高鐵假期" target="_blank">高鐵假期</a>
# <li class="top_24hours">
#                                 <a href="https://irs.thsrc.com.tw/IMINT?locale=tw" alt = "24小時網路訂票" title = "24小時網路訂票" target="_blank">24小時網路訂票</a>
#
#     </ul>
# </nav>
#
#         </header><h2>很抱歉，目前的網頁連結並不存在</h2>
#         <article>
# 	        <p>您輸入的網址不存在或頁面資訊已過期，造成您的不便，敬請見諒！</p>
# 	        <p>提醒您，台灣高鐵已進行全新改版，網站內的連結網址可能有所變動，若您曾加入我的最愛，需請您重新設定。</p>
# 	        <h3>本頁面將於 <strong><span class="sec"></span>秒</strong>後自動轉至<a href="/tw/Home">台灣高鐵官網首頁</a>，或是您可點選下列您欲前往的網頁或直接聯絡客服人員，謝謝！ </h3>
#         </article>
#         <ul class="list_link">
# 	        <li>台灣高鐵首頁：<a href="/tw/Home">http://www.thsrc.com.tw</a></li>
# 	        <li>24h網路訂票系統：<a href="https://irs.thsrc.com.tw/IMINT/">https://irs.thsrc.com.tw/IMINT/</a></li>
# 	        <li>高鐵假期：<a href="http://tholiday.thsrc.com.tw/">http://tholiday.thsrc.com.tw/</a></li>
#         </ul>
#
#         <aside class="phone_number">
# 	        <h4>苗栗：4266-3000 台東、金門：4666-3000 馬祖及行動電話：02-4066-3000 <strong>以上皆為付費電話，依一般市話及行動電話費率標準計費</strong></h4>
# 	        <h4 class="h42">苗栗：4266-0000 台東、金門：4666-0000 馬祖及行動電話：02-4066-0000 <em>服務時間：06:00~24:00</em></h4>
#         </aside>
#         <h6>台灣高速鐵路股份有限公司 版權所有 © 2013 Taiwan High Speed Rail Corporation. All Rights Reserved.</h6>
#     </div>
# </body>
# </html>
#     <script type="text/javascript">
#
#         $().ready(function () {
#             Reciprocal(10);
#         });
#
#         function Reciprocal(num) {
#             if (num == 0) {
#                 $('.sec').html(num);
#                 OK();
#             }
#             else if (num > 0) {
#                 setTimeout("Reciprocal(" + (num - 1) + ");", 1000);
#                 $('.sec').html(num);
#             }
#         }
#
#         function OK() {
#             location.href = "/tw/Home";
#         }
#
#     </script>

# %% [markdown]
# ## 將網頁讀進BeautifulSoup 中

# %%
from BeautifulSoup import BeautifulSoup 
html_sample = ' \
<html> \
 <body> \
 <h1 id="title">Hello World</h1> \
 <a href="#" class="link">This is link1</a> \
 <a href="# link2" class="link">This is link2</a> \
 </body> \
 </html>'

soup = BeautifulSoup(html_sample)
print soup.text
# Out:
# Hello WorldThis is link1This is link2

# %% [markdown]
# ## 使用Find 找出(第一個)含有a tag 的元素

# %%
soup = BeautifulSoup(html_sample) 
alink = soup.find('a') 
print alink
# Out:
# <a href="#" class="link">This is link1</a>

# %% [markdown]
# ## 找出所有含a tag 的HTML 元素

# %%
for alink in soup.findAll('a'): 
    print alink.contents
# Out:
# [u'This is link1']
# [u'This is link2']

# %% [markdown]
# ## 使用Find 找出所有id為title的元素

# %%
alink = soup.find('h1', {'id':'title'}) 
print alink
# Out:
# <h1 id="title">Hello World</h1>

# %% [markdown]
# ## 取得含有特定class的元素

# %%
soup = BeautifulSoup(html_sample) 
for link in soup.findAll('a', {'class': 'link'}): 
    print link
# Out:
# <a href="#" class="link">This is link1</a>
# <a href="# link2" class="link">This is link2</a>

# %% [markdown]
# ## 取得所有a tag 內的連結

# %%
alinks = soup.findAll('a', {'href': True}) 
for link in alinks: 
    print link['href']
# Out:
# #
# # link2

# %% [markdown]
# ## 設定POST 的Form Data

# %%
# -*- coding: utf-8 -*- 
import requests

payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

# %% [markdown]
# ## 送出Post 取得資料

# %%
user_post = requests.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
response_text = user_post.text.encode('utf8') 
#print response_text

# %% [markdown]
# ## 如何擷取高鐵時刻表?

# %%
### Please Write Your Own Code Here
url = 'http://www.thsrc.com.tw/tw/TimeTable/SearchResult'

# %% [markdown]
# ## 台鐵時刻表查詢

# %%
### Please Write Your Own Code Here
url = 'http://twtraffic.tra.gov.tw/twrail/EasySearch.aspx'

# %% [markdown]
# ## 如何延續Session

# %%
# -*- coding: utf-8 -*- 
import requests

payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

# %%
rs = requests.session() 
rs_post = rs.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
rs_get = rs.get("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2") 
response = rs_get.text.encode('utf8')

# %% [markdown]
# ## 取得資料筆數

# %%
from BeautifulSoup import BeautifulSoup

user_post = requests.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
response_text = user_post.text.encode('utf8') 
soup = BeautifulSoup(response_text) 
rec_number_element = soup.find('span', { "class" : "T11b" }) 
rec_number = int(rec_number_element.text) 
print rec_number
# Out:
# 265

# %% [markdown]
# ## 將資料筆數轉換成頁數

# %%
from math import ceil 
page_number = int(ceil(float(rec_number) / 100)) 
print page_number
# Out:
# 3

# %% [markdown]
# ## 字串格式化 - 使用format

# %%
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={0}" 
for page in range(1, page_number + 1): 
    print page_format.format(page)
# Out:
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3

# %% [markdown]
# ## 使用%

# %%
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    print page_format%(page)
# Out:
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3

# %% [markdown]
# ## 取得每頁標案清單的內容

# %%
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8')
    #print bid_response

# %% [markdown]
# ## 先拿一頁做試驗

# %%
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
page = 1 
bid_list = rs.get(page_format%(page)) 
bid_response = bid_list.text.encode('utf8') 
bid_soup = BeautifulSoup(bid_response) 
bid_table = bid_soup.find('div', { "id" : "print_area" }) 
print bid_table
# Out:
# <div id="print_area">
# <table width="100%" border="0" cellspacing="0" cellpadding="0" style="word-break:break-all">
# <tr>
# <td width="5%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">項次&nbsp;</td>
# <td width="15%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">機關&nbsp;<br />名稱&nbsp;</td>
# <td width="30%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">標案案號&nbsp;<br />標案名稱&nbsp;</td>
# <td width="10%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">招標&nbsp;<br />方式&nbsp;</td>
# <td width="8%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">標的&nbsp;<br />分類&nbsp;</td>
# <td width="9%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">公告&nbsp;<br />日期&nbsp;</td>
# <td width="13%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">決標&nbsp;<br />金額&nbsp;</td>
# <td width="5%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">決標&nbsp;<br />公告&nbsp;</td>
# <td width="5%" align="center" bgcolor="#E0EDF1" class="T12b" nowrap="nowrap">無法&nbsp;<br />決標&nbsp;</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">1&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">嘉義縣竹崎鄉公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												4197
#
# 												<font color="red">(更正公告)</font>
# <br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239371&amp;tenderCaseNo=4197">
# <u>竹崎鄉納骨堂業務資訊化管理系統建置</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/05/07
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													490000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239371&amp;tenderCaseNo=4197">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">2&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺灣糖業股份有限公司</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												0607L1030328
#
# 												<font color="red">(更正公告)</font>
# <br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239291&amp;tenderCaseNo=0607L1030328">
# <u>電話交換機維護保養</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/30
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													301500
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239291&amp;tenderCaseNo=0607L1030328">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">3&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國防部軍備局中山科學研究院</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												XW03118P099
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241675&amp;tenderCaseNo=XW03118P099">
# <u>載具補土噴漆作業等1項</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													141000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241675&amp;tenderCaseNo=XW03118P099">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">4&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國防部軍備局中山科學研究院</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												XW03072P119
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241674&amp;tenderCaseNo=XW03072P119">
# <u>裝步戰鬥車電子技令系統維護等1項</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													229383
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241674&amp;tenderCaseNo=XW03072P119">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">5&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣交響樂團</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												B1030411
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241666&amp;tenderCaseNo=B1030411">
# <u>童話‧傳奇-Ⅸ【唐璜愛之死】音樂會邀請獨奏家</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241666&amp;tenderCaseNo=B1030411">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">6&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣交響樂團</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												B1030422
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241665&amp;tenderCaseNo=B1030422">
# <u>童話‧傳奇-X【後宮傳奇-天方夜譚】音樂會邀請獨奏家</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# </td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241665&amp;tenderCaseNo=B1030422">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">7&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">交通部航港局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												MPB10390429
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241621&amp;tenderCaseNo=MPB10390429">
# <u>103年度公文系統維護案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													675000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241621&amp;tenderCaseNo=MPB10390429">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">8&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立霧峰高級農工職業學校</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-19
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241602&amp;tenderCaseNo=103-19">
# <u>「103學年度新生健康檢查」招標案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													182000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241602&amp;tenderCaseNo=103-19">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">9&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立清華大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												SL-103043
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241573&amp;tenderCaseNo=SL-103043">
# <u>103年教育部國教署補助各縣市增置國小教師員額經費管制及人力運用平台之系統維運案*1</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													365000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241573&amp;tenderCaseNo=SL-103043">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">10&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國防部軍醫局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												NG03035P009P
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241557&amp;tenderCaseNo=NG03035P009P">
# <u>影印機租賃</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													678960
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241557&amp;tenderCaseNo=NG03035P009P">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">11&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺中市中區光復國民小學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												10302
#
# 												<font color="red">(更正公告)</font>
# <br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241458&amp;tenderCaseNo=10302">
# <u>臺中市中區光復國民小學103年度「平等街棟」校舍耐震能力補強設計監造委託技術服務</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													600000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241458&amp;tenderCaseNo=10302">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">12&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣工藝研究發展中心</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-2-010
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241498&amp;tenderCaseNo=103-2-010">
# <u>「植物纖維工藝文化專輯出版計畫」委託服務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													635000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241498&amp;tenderCaseNo=103-2-010">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">13&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立陽明大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												W103ABC071
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241496&amp;tenderCaseNo=W103ABC071">
# <u>「綠光世界劇場-手牽手紀念日」表演費</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													198500
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241496&amp;tenderCaseNo=W103ABC071">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">14&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">金門縣物資處</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103230330119
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241485&amp;tenderCaseNo=103230330119">
# <u>103年度汰換水量計</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													830000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241485&amp;tenderCaseNo=103230330119">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">15&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺中市立清海國民中學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												C1030415
#
# 												<font color="red">(更正公告)</font>
# <br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51238144&amp;tenderCaseNo=C1030415">
# <u>102學年度9年級校外教學活動</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													186240
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51238144&amp;tenderCaseNo=C1030415">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">16&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺北市政府勞動局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												Y103016
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241358&amp;tenderCaseNo=Y103016">
# <u>勞工教育館建築物結構補強、屋頂外牆防漏及室內裝修復原工程設計監造委託案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													588000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241358&amp;tenderCaseNo=Y103016">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">17&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺中市太平區宜欣國民小學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103003
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241301&amp;tenderCaseNo=103003">
# <u>宜欣國民小學辦理103年度文小6學校預定地環境清潔維護採購</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													75000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241301&amp;tenderCaseNo=103003">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">18&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺中市政府文化局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-7
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241289&amp;tenderCaseNo=103-7">
# <u>2014下半年假日廣場系列活動</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													889000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241289&amp;tenderCaseNo=103-7">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">19&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">桃園縣桃園市公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-TY-142
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241135&amp;tenderCaseNo=103-TY-142">
# <u>103年度桃園市文化夏令營服務案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													300000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241135&amp;tenderCaseNo=103-TY-142">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">20&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">宜蘭縣史館</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030404
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241115&amp;tenderCaseNo=1030404">
# <u>《歸鄉四十年－龜山島影像誌》印製</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													129000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241115&amp;tenderCaseNo=1030404">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">21&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立西螺高級農工職業學校</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												11-1030328
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241108&amp;tenderCaseNo=11-1030328">
# <u>建構適性多元發展整合平台</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													205000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241108&amp;tenderCaseNo=11-1030328">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">22&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">基隆市政府</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												P103001
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241103&amp;tenderCaseNo=P103001">
# <u>103年基隆市政府一級主管(含秘書、參議)及所屬機關首長健康檢查</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													630000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241103&amp;tenderCaseNo=P103001">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">23&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">彰化縣政府</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-0021002-029-2-6
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241099&amp;tenderCaseNo=103-0021002-029-2-6">
# <u>彰化縣身心障礙者在家就業輔導計畫</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													763396
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241099&amp;tenderCaseNo=103-0021002-029-2-6">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">24&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">新北市政府衛生局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103075
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241063&amp;tenderCaseNo=103075">
# <u>103年度[新北市金山區國際安全社區推動計畫委託專業服務]</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													400000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241063&amp;tenderCaseNo=103075">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">25&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立清華大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												SL-103050
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241062&amp;tenderCaseNo=SL-103050">
# <u>103年度高解析X光光電子能譜儀(HRXPS)維護合約乙份</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													300000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241062&amp;tenderCaseNo=SL-103050">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">26&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">中央銀行</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030011069
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241029&amp;tenderCaseNo=1030011069">
# <u>入侵偵測防禦系統維護案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													140509
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51241029&amp;tenderCaseNo=1030011069">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">27&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立清華大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												SL-103046
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240942&amp;tenderCaseNo=SL-103046">
# <u>委託元件代工製造及高頻電性量測1批</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													358000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240942&amp;tenderCaseNo=SL-103046">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">28&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">南開科技大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												B102RD03012
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240875&amp;tenderCaseNo=B102RD03012">
# <u>AISP情報顧問資料庫</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													180000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240875&amp;tenderCaseNo=B102RD03012">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">29&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030203
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240824&amp;tenderCaseNo=1030203">
# <u>Codar長距離遙測站維護</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													550000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240824&amp;tenderCaseNo=1030203">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">30&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立陽明大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												G103EDU043
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240739&amp;tenderCaseNo=G103EDU043">
# <u>西安樓宿舍FTTB+Hinet網路租賃</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													134400
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240739&amp;tenderCaseNo=G103EDU043">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">31&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺北市萬華區萬大國民小學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103B04
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240712&amp;tenderCaseNo=103B04">
# <u>103年度跑道整修工程委託設計監造技術服務勞務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													149000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240712&amp;tenderCaseNo=103B04">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">32&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣科技大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												AASC-103085
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240655&amp;tenderCaseNo=AASC-103085">
# <u>103年實驗室廢液清運(預估廢棄藥品清運390公斤廢液清運17,000公斤)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													179150
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240655&amp;tenderCaseNo=AASC-103085">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">33&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺南市政府文化局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												TC103C036
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240623&amp;tenderCaseNo=TC103C036">
# <u>湯德章紀念公園國父銅像修復勞務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													528000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240623&amp;tenderCaseNo=TC103C036">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">34&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												DPD2014041101
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240622&amp;tenderCaseNo=DPD2014041101">
# <u>台北捷運燈箱廣告採購案(台北車站/公車候車亭)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													112500
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240622&amp;tenderCaseNo=DPD2014041101">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">35&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">南投縣竹山鎮公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103B018
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240570&amp;tenderCaseNo=103B018">
# <u>103年度災害搶險搶修開口契約委託點工 (富州、中央、社寮、山崇、坪頂、鯉魚等6里)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													163654
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240570&amp;tenderCaseNo=103B018">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">36&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立高雄餐旅大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												NKUHT1524-10310
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240557&amp;tenderCaseNo=NKUHT1524-10310">
# <u>就業學程模組</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													270000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240557&amp;tenderCaseNo=NKUHT1524-10310">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">37&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立臺灣大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												DPD2014041102
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240543&amp;tenderCaseNo=DPD2014041102">
# <u>台北捷運車廂廣告採購案(市政府站/世貿站/公館站)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													337500
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240543&amp;tenderCaseNo=DPD2014041102">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">38&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">新北市中和區光復國民小學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												10310
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240536&amp;tenderCaseNo=10310">
# <u>103學年度新(增)設附設幼兒園委託技術服務案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													151602
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240536&amp;tenderCaseNo=10310">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">39&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">行政院農業委員會畜產試驗所新竹分所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103A011A
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240484&amp;tenderCaseNo=103A011A">
# <u>刀鋒機組用之乳牛關聯資料庫系統優化與週邊模組整合(SMDF)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													190000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240484&amp;tenderCaseNo=103A011A">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">40&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立聯合大學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103M602
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240279&amp;tenderCaseNo=103M602">
# <u>103年度工程科技研究中心TAF延展評鑑</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													134300
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240279&amp;tenderCaseNo=103M602">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">41&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">金門縣物資處</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103310230121
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240240&amp;tenderCaseNo=103310230121">
# <u>金門縣參加103年全國身心障礙國民運動會活動（單價決標）</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													319000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240240&amp;tenderCaseNo=103310230121">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">42&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">金門縣物資處</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103430930099
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240202&amp;tenderCaseNo=103430930099">
# <u>遺體冷凍櫃更新工程委託規劃設計暨監造服務案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													360000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51240202&amp;tenderCaseNo=103430930099">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">43&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">教育部體育署</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-02-011
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239231&amp;tenderCaseNo=103-02-011">
# <u>本署103年度委託辦理「打造運動島資訊平臺-臺灣i運動維護及行銷計畫案」</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2160000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239231&amp;tenderCaseNo=103-02-011">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">44&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">教育部體育署</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												102-01-009
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239232&amp;tenderCaseNo=102-01-009">
# <u>本署國訓中心103年度培訓隊租車案(開口契約)</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													474000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239232&amp;tenderCaseNo=102-01-009">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">45&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">教育部體育署</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-02-033
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239233&amp;tenderCaseNo=103-02-033">
# <u>本署103年度內網(Intranet)系統增修暨維護服務委辦案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													499900
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239233&amp;tenderCaseNo=103-02-033">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">46&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">教育部體育署</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-02-029
#
# 												<br />
# ...
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">87&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">新北市政府市場處</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-A-09
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239319&amp;tenderCaseNo=103-A-09">
# <u>新北市各公有市場、攤販集中場(區)水電零星維護作業(開口契約)案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2348346
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239319&amp;tenderCaseNo=103-A-09">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">88&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">桃園縣桃園市公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-TY-137
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239481&amp;tenderCaseNo=103-TY-137">
# <u>藝文中心電梯主機循環油更換</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													120000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239481&amp;tenderCaseNo=103-TY-137">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">89&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">台灣電力股份有限公司興達發電廠</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												3410300075-S03023
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239468&amp;tenderCaseNo=3410300075-S03023">
# <u>複三、四、五機熱回收鍋爐旁通風門大修工作</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2680000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239468&amp;tenderCaseNo=3410300075-S03023">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">90&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺北縣蘆洲市蘆洲國民小學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												P9903
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239482&amp;tenderCaseNo=P9903">
# <u>舊和平樓A棟及B棟校舍補強設計委託技術服務</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													275052
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239482&amp;tenderCaseNo=P9903">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">91&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">財團法人台北市文化基金會</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103FC002
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239486&amp;tenderCaseNo=103FC002">
# <u>《台北工廠2 Taipei Factory 2》委託專業服務B組</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2249880
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239486&amp;tenderCaseNo=103FC002">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">92&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">高雄市政府工務局新建工程處</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030318
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239487&amp;tenderCaseNo=1030318">
# <u>「103年服務品質暨廉政實況問卷調查」委託民意調查</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													140000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239487&amp;tenderCaseNo=1030318">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">93&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">高雄市政府農業局</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												A103000002
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239509&amp;tenderCaseNo=A103000002">
# <u>103年高雄市玉荷包啤酒節暨農產品展售活動執行規劃</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													7950000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239509&amp;tenderCaseNo=A103000002">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">94&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">經濟部水利署</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030228
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239510&amp;tenderCaseNo=1030228">
# <u>各用水標的事業所需合理用水量檢討及其計算系統改善計畫（2/2）</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(未經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													1786000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239510&amp;tenderCaseNo=1030228">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">95&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺北榮民總醫院桃園分院</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												Jcs-1030501
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239514&amp;tenderCaseNo=Jcs-1030501">
# <u>【透析廢棄物(代號C-0508)及廢尖銳器具(代號C-0504)委託清除（運）回收處理作業】招標案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													129600
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239514&amp;tenderCaseNo=Jcs-1030501">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">96&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">臺中市立大墩國民中學</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030401
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239526&amp;tenderCaseNo=1030401">
# <u>臺中市政府教育局業務及重大教育政策平面媒體廣宣勞務採購案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													795000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239526&amp;tenderCaseNo=1030401">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">97&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">交通部民用航空局南竿航空站</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												NF103001
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239530&amp;tenderCaseNo=NF103001">
# <u>103及104年電力、給水、消防及空調系統維護操作勞務採購</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">限制性招標(經公開評選或公開徵求)</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													9920000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239530&amp;tenderCaseNo=NF103001">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">98&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">新北市新莊區公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												1030402B3
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239531&amp;tenderCaseNo=1030402B3">
# <u>新莊區中港里傳統技術文化暨生態保護研習活動</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													433920
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239531&amp;tenderCaseNo=1030402B3">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#FFFFFF" onmouseover="overcss(this);" onmouseout="outcss(this,'#FFFFFF');">
# <!-- 項次 -->
# <td align="center">99&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">桃園縣中壢市公所</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												103-03-080
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239533&amp;tenderCaseNo=103-03-080">
# <u>103年度中壢市公用路燈查驗定位及原有路燈報修電腦系統維護更新案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開取得報價單或企劃書</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													700000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239533&amp;tenderCaseNo=103-03-080">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr bgcolor="#D6FAC5" onmouseover="overcss(this);" onmouseout="outcss(this,'#D6FAC5');">
# <!-- 項次 -->
# <td align="center">100&nbsp;</td>
# <!-- 機關名稱 -->
# <td align="left">國立故宮博物院</td>
# <!-- 標案案號&amp;標案名稱 -->
# <td align="left">
# 												NPM103037
#
# 												<br />
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239537&amp;tenderCaseNo=NPM103037">
# <u>大觀–北宋汝窯特展圖錄等7項出版品加印案</u>
# </a>
# </td>
# <!-- 招標方式 -->
# <td align="left">公開招標</td>
# <!-- 標的分類 -->
# <td align="left">勞務類</td>
# <!-- 公告日期 -->
# <td align="center">103/04/29
# </td>
# <!-- 決標金額 -->
# <td align="right">
# 													2394000
# 												</td>
# <!-- 決標公告 -->
# <td align="center">
# <a href="../main/pms/tps/atm/atmAwardAction.do?newEdit=false&amp;searchMode=common&amp;method=inquiryForPublic&amp;pkAtmMain=51239537&amp;tenderCaseNo=NPM103037">
# <u>001</u>
# </a>
#
# 													&nbsp;
# 												</td>
# <!-- 無法決標公告 -->
# <td align="center">
# 													&nbsp;
# 												</td>
# </tr>
# <tr>
# <td colspan="11" align="center" bgcolor="#E0EDF1" class="T11">
# 											[第一頁/上一頁]
#
# 												&lt;<b>1</b>&gt;
#
#
#
# 												,
#
#
# 													<a style="color: #444444;" href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=2"><b>2</b></a>
#
#
#
# 												,
#
#
# 													<a style="color: #444444;" href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=3"><b>3</b></a>
#
#
# 											 [
# 												<a style="color: #444444;" href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=2">下一頁</a>
# 											/
# 												<a style="color: #444444;" href="./tender.do?searchMode=common&amp;searchType=advance&amp;searchTarget=ATM&amp;method=search&amp;isSpdt=&amp;pageIndex=3">最後一頁</a>
# 											] 共有<span class="T11b" style="color: red;">265</span>筆資料</td>
# </tr>
# </table>
# </div>

# %% [markdown]
# ## 去掉標頭

# %%
bid_rows = bid_table.findAll('tr')[1:] 
#print bid_rows

# %% [markdown]
# ## 去掉標頭跟頁次

# %%
bid_rows = bid_table.findAll('tr')[1:-1] 
#print bid_rows

# %% [markdown]
# ## 索引範例

# %%
ary = [1,2,3,4,5,6] 
print ary[1:-1] 
#[2,3,4,5]
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# ## 抓出每一列所有的連結

# %%
bid_rows = bid_table.findAll('tr')[1:-1] 
for bid_row in bid_rows: 

    links = [tag['href'] 
      for tag in bid_row.findAll('a', {'href': True})] 

    #print links

# %% [markdown]
# ## 用[0]取第一個連結

# %%
for bid_row in bid_rows: 

    links = [tag['href'] 
      for tag in bid_row.findAll('a', {'href': True})][0]
 
    #print links

# %% [markdown]
# ## 取得實際連結

# %%
for bid_row in bid_rows: 
    link = [tag['href'] 
      for tag in bid_row.findAll('a',{'href': True})][0] 

    link_href = "http://web.pcc.gov.tw/tps" + link[2:] 

    #print link_href

# %% [markdown]
# ## 使用urljoin

# %%
import urlparse
for bid_row in bid_rows: 
    link = [tag['href'] 
      for tag in bid_row.findAll('a',{'href': True})][0] 

    link_href = urlparse.urljoin("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", link)

    #print link_href

# %% [markdown]
# ## 複習一下如何使用Python做檔案寫入

# %%
f = open("test.txt", 'w') 
f.write("Hello World\n") 
f.close()

# %% [markdown]
# ## 將每頁標案清單的連結存入檔案

# %%
bid_file = open("bid_list.txt", 'w') 
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response) 
    bid_table = bid_soup.find('div', { "id" : "print_area" }) 
    bid_rows = bid_table.findAll('tr')[1:-1] 
    for bid_row in bid_rows:         
        link = [tag['href'] for tag in bid_row.findAll('a', {'href': True})][0] 
        link_href = urlparse.urljoin("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", link) 
        bid_file.write(link_href + "\n") 
bid_file.close()

# %% [markdown]
# ## 0. 引入該用的package

# %%
import requests
import urlparse 
from BeautifulSoup import BeautifulSoup 
from math import ceil

# %% [markdown]
# ## 1. 設定查詢條件

# %%
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

rs = requests.session() 
user_post = rs.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
response_text = user_post.text.encode('utf8')

# %% [markdown]
# ## 2. 計算抓取頁數

# %%
soup = BeautifulSoup(''.join(response_text)) 
rec_number_element = soup.find('span', { "class" : "T11b" }) 
rec_number = int(rec_number_element.text)
page_number = int(ceil(float(rec_number) / 100))

# %% [markdown]
# ## 3. 依每頁抓取所有標案連結 &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4. 存入每頁標案連結

# %%
bid_file = open("bid_list.txt", 'w') 
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response)
    bid_table = bid_soup.find('div', { "id" : "print_area" }) 
    bid_rows = bid_table.findAll('tr')[1:-1] 
    for bid_row in bid_rows: 
        link = [tag.attrMap['href'] for tag in bid_row.findAll('a', {'href': True})][0] 
        link_href = urlparse.urljoin("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", link) 
        bid_file.write(link_href + "\n") 
bid_file.close()

# %% [markdown]
# ## 計算總共存了多少個連結

# %%
line_num = 0 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    line_num = line_num + 1 
print line_num 
f.close()
# Out:
# 265

# %% [markdown]
# ## 判斷抓下來的資料筆數
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 是否與網頁上呈現的相同

# %%
soup = BeautifulSoup(''.join(response_text)) 
rec_number_element = soup.find('span', { "class" : "T11b" }) 
rec_number = int(rec_number_element.text)

line_num = 0 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    line_num = line_num + 1 
print line_num 
f.close() 

#使用if 判斷
if rec_number == line_num: 
    print "record number on web page is equal to number of lines in file"
# Out:
# 265
# record number on web page is equal to number of lines in file

# %% [markdown]
# ## 使用requests.get 抓取標案細節

# %%
request_get = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
#print response

# %% [markdown]
# ## 取得id為printArea 的區塊

# %%
request_get = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.find('div', { "id" : "printArea" }) 
#print printarea

# %% [markdown]
# ## 將標案資料寫進檔案中

# %%
bid_detail = open("bid_detail.txt", 'w') 
request_get = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.find('div', { "id" : "printArea" }) 
bid_detail.write(printarea) 
bid_detail.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-1f93b4e1636c> in <module>()
#       4 soup = BeautifulSoup(response)
#       5 printarea = soup.find('div', { "id" : "printArea" })
# ----> 6 bid_detail.write(printarea)
#       7 bid_detail.close()
#
# TypeError: expected a character buffer object

# %% [markdown]
# ## 使用prettify 將soup 抓到的tag
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 轉換成str

# %%
bid_detail = open("bid_detail.txt", 'w') 
request_get = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.find('div', { "id" : "printArea" }) 
bid_detail.write(printarea.prettify("utf-8")) 
bid_detail.close()

# %% [markdown]
# ## 怎麼找出案號是否會重複?

# %%
case_dic = {} 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    rec = line.strip() 
    caseno = rec.split('tenderCaseNo=')[1] 
    if caseno not in case_dic: 
        case_dic[caseno] = 1 
    else: 
        print caseno 
f.close()
# Out:
# 1030401
# 1030415
# 10302
# 10302
# 103003

# %% [markdown]
# ## 如何從url 取得這兩個值?

# %%
link = "http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328"

# %% [markdown]
# ## 使用split

# %%
rear_substring = link.split("pkAtmMain=")[1] 
param = rear_substring.split("&tenderCaseNo=") 
pkAtmMain= param[0] 
caseno= param[1] 
print pkAtmMain,caseno
# Out:
# 51239291 0607L1030328

# %% [markdown]
# ## re.match 範例

# %%
import re 
m = re.match(r"(?P<FirstName>\w+) (?P<LastName>\w+)", "David Chiu") 
print m.group("FirstName"), m.group("LastName")
# Out:
# David Chiu

# %% [markdown]
# ## 使用re.match

# %%
import re 
link = "http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51239291&tenderCaseNo=0607L1030328" 
m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>\w+)&tenderCaseNo=(?P<tenderCaseNo>\w+)", link) 
print m.group('pkAtmMain'), m.group('tenderCaseNo')
# Out:
# 51239291 0607L1030328

# %% [markdown]
# ## 讀取bid_list.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 依序抓出標案內容

# %%
from BeautifulSoup import BeautifulSoup 
import re, requests, time 

bid_list = open('bid_list.txt', 'r') 
for line in bid_list.readlines(): 
    pagelink = line.strip() 
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>\w+)&tenderCaseNo=(?P<tenderCaseNo>\w+)", pagelink) 
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response)
    printarea = soup.find('div', { "id" : "printArea" }) 
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea .prettify("utf-8")) 
    bid_detail.close() 
    print filename
    time.sleep(0.2)
bid_list.close()

# %% [markdown]
# ## 抓取標案細節完成版

# %%
# -*- coding: utf-8 -*- 
from BeautifulSoup import BeautifulSoup 
import re, requests, time 

bid_list = open('bid_list.txt', 'r') 
for line in bid_list.readlines(): 
    pagelink = line.strip() 
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>\w+)&tenderCaseNo=(?P<tenderCaseNo>\w+)", pagelink)  
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response)
    printarea = soup.find('div', { "id" : "printArea" }) 
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea .prettify("utf-8")) 
    bid_detail.close() 
    print filename
    time.sleep(1)
bid_list.close()

# %% [markdown]
# ## Findbook 詢價

# %%
import requests
import time 
booklist = [9789863021582, 9789866031472]
find_url = 'http://findbook.tw/book/%s/basic'
for book in booklist:
    f = open('%s.html'%(book), 'w')
    res = requests.get(find_url%(book))
    f.write(res.text.encode('utf-8'))
    f.close()
    time.sleep(1)

# %% [markdown]
# ## 取得頁面的encoding

# %%
import requests
import time 
res = requests.get('http://findbook.tw/book/9789863021582/basic')
print res.encoding
# Out:
# ISO-8859-1

# %% [markdown]
# ## 更改response 的encoding

# %%
import requests
import time 
res = requests.get('http://findbook.tw/book/9789863021582/basic')
res.encoding= 'utf-8'
print res.encoding
# Out:
# utf-8

# %% [markdown]
# ## 再度修改程式

# %%
import requests
import time 

booklist = ['9789863021582', '9789866031472']
find_url = 'http://findbook.tw/book/%s/basic'
for book in booklist:
    f = open('%s.html'%(book), 'w')
    res = requests.get(find_url%(book))
    res.encoding= 'utf-8'
    f.write(res.text.encode('utf-8'))
    f.close()
    time.sleep(1)

# %% [markdown]
# ## 用爬蟲取得PTT資訊

# %%
import requests
res = requests.get('http://www.ptt.cc/bbs/Food/index.html')
print res.text

# %% [markdown]
# ## 新增Verify 的選項

# %%
import requests
res = requests.get('http://www.ptt.cc/bbs/Food/index.html', verify=False)
#print res.text

# %% [markdown]
# ## 取得所有連結

# %%
import requests
from BeautifulSoup import BeautifulSoup
res = requests.get('http://www.ptt.cc/bbs/Food/index.html', verify=False)
soup = BeautifulSoup(res.text)
links = [tag['href'] for tag in soup.findAll('a', {'href': True})] 
print links
# Out:
# [u'/', u'/bbs/Food/index.html', u'/about.html', u'/contact.html', u'/bbs/Food/index.html', u'/man/Food/index.html', u'/bbs/Food/index1.html', u'/bbs/Food/index3246.html', u'/bbs/Food/index.html', u'/bbs/Food/M.1403251359.A.58A.html', u'/bbs/Food/M.1403251878.A.266.html', u'/bbs/Food/M.1403252685.A.A82.html', u'/bbs/Food/M.1403253710.A.757.html', u'/bbs/Food/M.1403254647.A.9CF.html', u'/bbs/Food/M.1403255116.A.E68.html', u'/bbs/Food/M.1403255163.A.678.html', u'/bbs/Food/M.1403257811.A.E3E.html', u'/bbs/Food/M.1403258322.A.3BD.html', u'/bbs/Food/M.1403258553.A.35E.html', u'/bbs/Food/M.1403260654.A.DC6.html', u'/bbs/Food/M.1403261199.A.6A7.html', u'/bbs/Food/M.1403261594.A.9F7.html', u'/bbs/Food/M.1403261960.A.526.html', u'/bbs/Food/M.1403262801.A.840.html', u'/bbs/Food/M.1403263259.A.4F0.html']

# %% [markdown]
# ## 用爬蟲取得Yahoo股市的投資組合

# %%
# -*- coding: utf-8 -*- 
import requests
from BeautifulSoup import BeautifulSoup
rs = requests.session()
res = rs.get('https://login.yahoo.com/')
soup = BeautifulSoup(res.text)
login_form = soup.find('form', attrs={'name':'login_form'})
hiddens = login_form.findAll('input', attrs={'type':'hidden'})
payload = {}
for h in hiddens:
    payload[str(h.get('name'))] = str(h.get('value'))

payload['login'] = 'xxx@yahoo.com.tw'
payload['passwd'] = 'xxx'
post_url = str(login_form.get('action'))
res2 = rs.post(post_url, cookies=res.cookies, data=payload)

# %% [markdown]
# ## 轉跳到投資組合頁面

# %%
res3 = rs.get('https://tw.stock.yahoo.com/pf/mypf', cookies=res2.cookies)
#print res3.text.encode('utf-8')

# %% [markdown]
# ## 取得Facebook的朋友清單

# %%
import requests
access_token = '<access_token>'
graph_url = 'https://graph.facebook.com/v2.0/me/friends?access_token=%s'
res = requests.get(graph_url%(access_token))
print res.text
